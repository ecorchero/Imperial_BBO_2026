# %%
import os
import numpy as np

# === 0. Base directory where all function folders live ===
# If your notebook is in that folder, this is fine:
base_dir = os.getcwd()

print("Base directory:", base_dir)
print("Contents:", os.listdir(base_dir))
# Out:
# Base directory: C:\Users\elena\Documents\BBO\Submissions\WEEK_04\data
# Contents: ['.ipynb_checkpoints', 'BBO_Update_ALL_short.ipynb', 'F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'function_summary.csv', 'week_04_BBO_Update_with_week_03_results.ipynb']

# %%
# 2A ---  reviews the current input and outputs (long version of the code, but easy to understand)

# --- F1 Load & Print ---
inputs_data  = np.load('F1/initial_inputs.npy')
outputs_data = np.load('F1/initial_outputs.npy')
print("\nF1 SHAPE - Inputs:", inputs_data.shape, "Outputs:", outputs_data.shape)
print("Last values - input:", inputs_data[-1:], "output:", outputs_data[-1:])

# --- F2 Load & Print ---
inputs_data  = np.load('F2/initial_inputs.npy')
outputs_data = np.load('F2/initial_outputs.npy')
print("\nF2 SHAPE - Inputs:", inputs_data.shape, "Outputs:", outputs_data.shape)
print("Last values - input:", inputs_data[-1:], "output:", outputs_data[-1:])

# --- F3 Load & Print ---
inputs_data  = np.load('F3/initial_inputs.npy')
outputs_data = np.load('F3/initial_outputs.npy')
print("\nF3 SHAPE - Inputs:", inputs_data.shape, "Outputs:", outputs_data.shape)
print("Last values - input:", inputs_data[-1:], "output:", outputs_data[-1:])

# --- F4 Load & Print ---
inputs_data  = np.load('F4/initial_inputs.npy')
outputs_data = np.load('F4/initial_outputs.npy')
print("\nF4 SHAPE - Inputs:", inputs_data.shape, "Outputs:", outputs_data.shape)
print("Last values - input:", inputs_data[-1:], "output:", outputs_data[-1:])

# --- F5 Load & Print ---
inputs_data  = np.load('F5/initial_inputs.npy')
outputs_data = np.load('F5/initial_outputs.npy')
print("\nF5 SHAPE - Inputs:", inputs_data.shape, "Outputs:", outputs_data.shape)
print("Last values - input:", inputs_data[-1:], "output:", outputs_data[-1:])

# --- F6 Load & Print ---
inputs_data  = np.load('F6/initial_inputs.npy')
outputs_data = np.load('F6/initial_outputs.npy')
print("\nF6 SHAPE - Inputs:", inputs_data.shape, "Outputs:", outputs_data.shape)
print("Last values - input:", inputs_data[-1:], "output:", outputs_data[-1:])

# --- F7 Load & Print ---
inputs_data  = np.load('F7/initial_inputs.npy')
outputs_data = np.load('F7/initial_outputs.npy')
print("\nF7 SHAPE - Inputs:", inputs_data.shape, "Outputs:", outputs_data.shape)
print("Last values - input:", inputs_data[-1:], "output:", outputs_data[-1:])

# --- F8 Load & Print ---
inputs_data  = np.load('F8/initial_inputs.npy')
outputs_data = np.load('F8/initial_outputs.npy')
print("\nF8 SHAPE - Inputs:", inputs_data.shape, "Outputs:", outputs_data.shape)
print("Last values - input:", inputs_data[-1:], "output:", outputs_data[-1:])
# Out:
# F1 SHAPE - Inputs: (13, 2) Outputs: (13,)
# Last values - input: [[0.550173 0.334047]] output: [-5.97482053e-18]
#
# F2 SHAPE - Inputs: (13, 2) Outputs: (13,)
# Last values - input: [[0.968363 0.557288]] output: [-0.02517897]
#
# F3 SHAPE - Inputs: (18, 3) Outputs: (18,)
# Last values - input: [[0.964021 0.021941 0.768711]] output: [-0.17852719]
#
# F4 SHAPE - Inputs: (33, 4) Outputs: (33,)
# Last values - input: [[0.415091 0.447439 0.379873 0.420895]] output: [0.19068381]
#
# F5 SHAPE - Inputs: (23, 4) Outputs: (23,)
# Last values - input: [[0.155843 0.7688   0.966134 0.998903]] output: [2131.7263508]
#
# F6 SHAPE - Inputs: (23, 5) Outputs: (23,)
# Last values - input: [[0.473482 0.222091 0.514218 0.907341 0.104698]] output: [-0.56286093]
#
# F7 SHAPE - Inputs: (33, 6) Outputs: (33,)
# Last values - input: [[0.029608 0.928878 0.45357  0.259055 0.107713 0.743326]] output: [0.18762882]
#
# F8 SHAPE - Inputs: (43, 8) Outputs: (43,)
# ...

# %%
# With x, we use axis=0 to append a new row.
# .reshape(1, -1) is crucial to turn the 1D array into a 2D row (1 row, 5 columns)
# In the case of Y, a 1D array, appending places the new element at the end by default.
# Since the new input row was also placed at the end, the correlation is maintained.


# --- F1 Load & Update ---
inputs_data  = np.load('F1/initial_inputs.npy')
outputs_data = np.load('F1/initial_outputs.npy')
new_x_row = np.array([0.550173, 0.334047])
new_y_value = np.array([-5.974820532207338e-18])
inputs_data_updated = np.append(inputs_data, new_x_row.reshape(1, -1), axis=0)
outputs_data_updated = np.append(outputs_data, new_y_value)
np.save("F1/initial_inputs.npy", inputs_data_updated)
np.save("F1/initial_outputs.npy", outputs_data_updated)
print("\nF1 SHAPE Before/after - Inputs:", inputs_data.shape, inputs_data_updated.shape, "Outputs:", outputs_data.shape, outputs_data_updated.shape)
print("Last values - input:", inputs_data_updated[-1:], "output:", outputs_data_updated[-1:])

# --- F2 Load & Update ---
inputs_data  = np.load('F2/initial_inputs.npy')
outputs_data = np.load('F2/initial_outputs.npy')
new_x_row = np.array([0.968363, 0.557288])
new_y_value = np.array([-0.025178967609873027])
inputs_data_updated = np.append(inputs_data, new_x_row.reshape(1, -1), axis=0)
outputs_data_updated = np.append(outputs_data, new_y_value)
np.save("F2/initial_inputs.npy", inputs_data_updated)
np.save("F2/initial_outputs.npy", outputs_data_updated)
print("\nF2 SHAPE Before/after - Inputs:", inputs_data.shape, inputs_data_updated.shape, "Outputs:", outputs_data.shape, outputs_data_updated.shape)
print("Last values - input:", inputs_data_updated[-1:], "output:", outputs_data_updated[-1:])

# --- F3 Load & Update ---
inputs_data  = np.load('F3/initial_inputs.npy')
outputs_data = np.load('F3/initial_outputs.npy')
new_x_row = np.array([0.964021, 0.021941, 0.768711])
new_y_value = np.array([-0.17852719226598684])
inputs_data_updated = np.append(inputs_data, new_x_row.reshape(1, -1), axis=0)
outputs_data_updated = np.append(outputs_data, new_y_value)
np.save("F3/initial_inputs.npy", inputs_data_updated)
np.save("F3/initial_outputs.npy", outputs_data_updated)
print("\nF3 SHAPE Before/after - Inputs:", inputs_data.shape, inputs_data_updated.shape, "Outputs:", outputs_data.shape, outputs_data_updated.shape)
print("Last values - input:", inputs_data_updated[-1:], "output:", outputs_data_updated[-1:])

# --- F4 Load & Update ---
inputs_data  = np.load('F4/initial_inputs.npy')
outputs_data = np.load('F4/initial_outputs.npy')
new_x_row = np.array([0.415091, 0.447439, 0.379873, 0.420895])
new_y_value = np.array([0.19068381112284571])
inputs_data_updated = np.append(inputs_data, new_x_row.reshape(1, -1), axis=0)
outputs_data_updated = np.append(outputs_data, new_y_value)
np.save("F4/initial_inputs.npy", inputs_data_updated)
np.save("F4/initial_outputs.npy", outputs_data_updated)
print("\nF4 SHAPE Before/after - Inputs:", inputs_data.shape, inputs_data_updated.shape, "Outputs:", outputs_data.shape, outputs_data_updated.shape)
print("Last values - input:", inputs_data_updated[-1:], "output:", outputs_data_updated[-1:])

# --- F5 Load & Update ---
inputs_data  = np.load('F5/initial_inputs.npy')
outputs_data = np.load('F5/initial_outputs.npy')
new_x_row = np.array([0.155843, 0.768800, 0.966134, 0.998903])
new_y_value = np.array([2131.7263507965113])
inputs_data_updated = np.append(inputs_data, new_x_row.reshape(1, -1), axis=0)
outputs_data_updated = np.append(outputs_data, new_y_value)
np.save("F5/initial_inputs.npy", inputs_data_updated)
np.save("F5/initial_outputs.npy", outputs_data_updated)
print("\nF5 SHAPE Before/after - Inputs:", inputs_data.shape, inputs_data_updated.shape, "Outputs:", outputs_data.shape, outputs_data_updated.shape)
print("Last values - input:", inputs_data_updated[-1:], "output:", outputs_data_updated[-1:])

# --- F6 Load & Update ---
inputs_data  = np.load('F6/initial_inputs.npy')
outputs_data = np.load('F6/initial_outputs.npy')
new_x_row = np.array([0.473482, 0.222091, 0.514218, 0.907341, 0.104698])
new_y_value = np.array([-0.5628609309232714])
inputs_data_updated = np.append(inputs_data, new_x_row.reshape(1, -1), axis=0)
outputs_data_updated = np.append(outputs_data, new_y_value)
np.save("F6/initial_inputs.npy", inputs_data_updated)
np.save("F6/initial_outputs.npy", outputs_data_updated)
print("\nF6 SHAPE Before/after - Inputs:", inputs_data.shape, inputs_data_updated.shape, "Outputs:", outputs_data.shape, outputs_data_updated.shape)
print("Last values - input:", inputs_data_updated[-1:], "output:", outputs_data_updated[-1:])

# --- F7 Load & Update ---
inputs_data  = np.load('F7/initial_inputs.npy')
outputs_data = np.load('F7/initial_outputs.npy')
new_x_row = np.array([0.029608, 0.928878, 0.453570, 0.259055, 0.107713, 0.743326])
new_y_value = np.array([0.18762882401993042])
inputs_data_updated = np.append(inputs_data, new_x_row.reshape(1, -1), axis=0)
outputs_data_updated = np.append(outputs_data, new_y_value)
np.save("F7/initial_inputs.npy", inputs_data_updated)
np.save("F7/initial_outputs.npy", outputs_data_updated)
print("\nF7 SHAPE Before/after - Inputs:", inputs_data.shape, inputs_data_updated.shape, "Outputs:", outputs_data.shape, outputs_data_updated.shape)
print("Last values - input:", inputs_data_updated[-1:], "output:", outputs_data_updated[-1:])

# --- F8 Load & Update ---
inputs_data  = np.load('F8/initial_inputs.npy')
outputs_data = np.load('F8/initial_outputs.npy')
new_x_row = np.array([0.218561, 0.098712, 0.161259, 0.808751, 0.956063, 0.936828, 0.012836, 0.995072])
new_y_value = np.array([9.2437064184911])
inputs_data_updated = np.append(inputs_data, new_x_row.reshape(1, -1), axis=0)
outputs_data_updated = np.append(outputs_data, new_y_value)
np.save("F8/initial_inputs.npy", inputs_data_updated)
np.save("F8/initial_outputs.npy", outputs_data_updated)
print("\nF8 SHAPE Before/after - Inputs:", inputs_data.shape, inputs_data_updated.shape, "Outputs:", outputs_data.shape, outputs_data_updated.shape)
print("Last values - input:", inputs_data_updated[-1:], "output:", outputs_data_updated[-1:])
# Out:
# F1 SHAPE Before/after - Inputs: (12, 2) (13, 2) Outputs: (12,) (13,)
# Last values - input: [[0.550173 0.334047]] output: [-5.97482053e-18]
#
# F2 SHAPE Before/after - Inputs: (12, 2) (13, 2) Outputs: (12,) (13,)
# Last values - input: [[0.968363 0.557288]] output: [-0.02517897]
#
# F3 SHAPE Before/after - Inputs: (17, 3) (18, 3) Outputs: (17,) (18,)
# Last values - input: [[0.964021 0.021941 0.768711]] output: [-0.17852719]
#
# F4 SHAPE Before/after - Inputs: (32, 4) (33, 4) Outputs: (32,) (33,)
# Last values - input: [[0.415091 0.447439 0.379873 0.420895]] output: [0.19068381]
#
# F5 SHAPE Before/after - Inputs: (22, 4) (23, 4) Outputs: (22,) (23,)
# Last values - input: [[0.155843 0.7688   0.966134 0.998903]] output: [2131.7263508]
#
# F6 SHAPE Before/after - Inputs: (22, 5) (23, 5) Outputs: (22,) (23,)
# Last values - input: [[0.473482 0.222091 0.514218 0.907341 0.104698]] output: [-0.56286093]
#
# F7 SHAPE Before/after - Inputs: (32, 6) (33, 6) Outputs: (32,) (33,)
# ...
